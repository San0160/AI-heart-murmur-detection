# %%
import os

# %%
# %pwd
# Out:
# 'c:\\Users\\Sandeep\\Desktop\\Projects\\AI-heart-murmur-detection\\reseach'

# %%
os.chdir("../")

# %%
# %pwd
# Out:
# 'c:\\Users\\Sandeep\\Desktop\\Projects\\AI-heart-murmur-detection'

# %%
# 3 entites update
# from config.ymal
from dataclasses import dataclass
from pathlib import Path

@dataclass(frozen = True)
class DataValidationConfig:
    root_dir: Path
    STATUS_FILE: str
    ALL_REQUIRED_FILES: Path

# %%
from HeartBeat.constant import *
from HeartBeat.utils.common import read_yaml, create_directories

# %%
# 4 Update configuration manager

class configurationManager:
    def __init__(
        self,
        config_filepath = CONFIG_FILE_PATH,     # Access to constants
        params_filepath = PARAMS_FILE_PATH):

        self.config = read_yaml(config_filepath) # read all config and params yaml files
        self.params = read_yaml(params_filepath)

        create_directories([self.config.artifacts_root])

    def get_data_validation_config(self) -> DataValidationConfig:
        config = self.config.data_validation

        create_directories([config.root_dir])

        data_validation_config = DataValidationConfig(
            root_dir = config.root_dir,
            STATUS_FILE = config.STATUS_FILE,
            ALL_REQUIRED_FILES = config.ALL_REQUIRED_FILES,
        )

        return data_validation_config

# %%
import os
from HeartBeat.logging import logger

# %%
# 5 Conponents

class DataValidation:
    def __init__(self, config: DataValidationConfig):
        self.config = config

    # simple python code that validates all files

    def validate_all_files_exists(self) -> bool:
        try:
            validation_status = None

            all_files = os.listdir(os.path.join("artifacts", "data_injection", "Heartbeat_sound"))

            for file in all_files:
                if file not in self.config.ALL_REQUIRED_FILES:
                    validation_status = False
                    with open(self.config.STATUS_FILE, "w") as f:
                        f.write(f"validation status: {validation_status}")
                
                else:
                    validation_status = True
                    with open(self.config.STATUS_FILE, "w") as f:
                        f.write(f"validation status: {validation_status}")

            return validation_status
        
        except Exception as e:
            raise e

# %%
# 6 Pipeline

try:
    config = configurationManager()
    data_validation_config = config.get_data_validation_config()
    data_validation = DataValidation(config = data_validation_config)
    data_validation.validate_all_files_exists()

except Exception as e:
    raise e
# Out:
# [2026-06-25 18:25:33,796: INFO: common: ymal file config\config.yaml loaded sucessfully]
# [2026-06-25 18:25:33,799: INFO: common: ymal file params.yaml loaded sucessfully]
# [2026-06-25 18:25:33,801: INFO: common: created directory at artifacts]
# [2026-06-25 18:25:33,805: INFO: common: created directory at artifacts/data_validation]
